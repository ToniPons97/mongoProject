# %%
import yelp_api as ya
import folium
from time import sleep
import pandas as pd
# %store -r cities_df

# %%
type(cities_df)

# %%
starbucks_list = []

for i in cities_df:
    starbucks_list.append(ya.get_coords("Starbucks", i))
    sleep(0.5)

# %%
for i in range(len(starbucks_list)):
    starbucks_list[i] = starbucks_list[i][starbucks_list[i].Name == "Starbucks"]

starbucks_list[0]

# %%
starbucks_dfs = pd.concat(starbucks_list)
starbucks_dfs

# %%
starbucks_dfs.to_json("../output/starbucks.json", orient="records")

# %%
airports_df = []
for i in cities_df:
    airports_df.append(ya.get_coords("Airport", i))
    sleep(0.5)
# Out:
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200

# %%
airports_dfs
# Out:
#                                      Name            City  Raiting  \
# 0                          Access Express        Plymouth      5.0
# 1                 Stella's Livery Service   Middleborough      5.0
# 2              Special Occasion Limousine        Plymouth      4.0
# 3    Long's Taxi & Airport Transportation  South Yarmouth      4.5
# 4                     Boston Limo Service         Needham      5.0
# ..                                    ...             ...      ...
# 45                          Taxi Bay Area     Santa Clara      1.0
# 46                                Sky Cab       Sunnyvale      4.0
# 47  Chauffeur Adamo - Airport Car Service     Santa Clara      5.0
# 48                           eCharter Bus     Santa Clara      4.5
# 49               Elite VIP Transportation       Los Gatos      5.0
#
#                               Coordinates  \
# 0               [-70.6943588, 41.9815521]
# 1   [-70.9068374633789, 41.8944511413574]
# 2                 [-70.651003, 41.925159]
# 3                   [-70.20273, 41.65892]
# 4                 [-71.228718, 42.305664]
# ..                                    ...
# 45  [-121.998000722876, 37.3532787321973]
# 46  [-122.058272829545, 37.3797654643653]
# 47               [-121.9971061, 37.34562]
# 48             [-121.9604938, 37.3757195]
# 49                 [-122.02665, 37.19276]
#
#                                              Geometry
# 0   {'Type': 'Point', 'coordinates': [-70.6943588,...
# 1   {'Type': 'Point', 'coordinates': [-70.90683746...
# 2   {'Type': 'Point', 'coordinates': [-70.651003, ...
# 3   {'Type': 'Point', 'coordinates': [-70.20273, 4...
# 4   {'Type': 'Point', 'coordinates': [-71.228718, ...
# ..                                                ...
# 45  {'Type': 'Point', 'coordinates': [-121.9980007...
# 46  {'Type': 'Point', 'coordinates': [-122.0582728...
# 47  {'Type': 'Point', 'coordinates': [-121.9971061...
# 48  {'Type': 'Point', 'coordinates': [-121.9604938...
# 49  {'Type': 'Point', 'coordinates': [-122.02665, ...
#
# [18557 rows x 5 columns]

# %%
airports_dfs.to_json("../output/airports.json", orient="records")

# %%
# Out:
# dtype('O')

# %%
#df_schools = ya.get_coords("Schools", "Los Angeles")
#df_web_design = ya.get_coords("Web Design", "Los Angeles")
#df_web_design

# %%
def generateBaseMap(default_location=[34.0397, -118.2703], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
df_Airport
df_Vegan = ya.get_coords("Vegan Restaurant", "Los Angeles")

# %%
base_map = generateBaseMap()
base_map.add_child(folium.ClickForMarker(popup='Potential Location'))
for i in df_starbucks["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="coffee", color="darkred") ,popup="Starbucks").add_to(base_map)
for i in df_schools["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="graduation-cap", color="blue") ,popup="Schools").add_to(base_map)
for i in df_web_design["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="paint-brush", color="green") ,popup="Web Design").add_to(base_map)
for i in df_Airport["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="plane", color="red") ,popup="Airport").add_to(base_map)
for i in df_Vegan["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="leaf", color="darkblue") ,popup="Vegan food").add_to(base_map)
base_map

# %%
df_Vegan
