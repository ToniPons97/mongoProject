# %%
import yelp_api as ya
import folium
from time import sleep
import pandas as pd
# %store -r cities_df

# %%
type(cities_df)
# Out:
# list

# %%
starbucks_list = []

for i in cities_df:
    starbucks_list.append(ya.get_coords("Starbucks", i))
    sleep(0.5)
# Out:
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200

# %%
starbucks_list[0]
# Out:
#                             Name      City  Raiting  \
# 0                      Starbucks  Plymouth      3.0
# 1                      Starbucks  Plymouth      2.5
# 2        Kiskadee Coffee Company  Plymouth      4.0
# 3            The Jolly Bean Cafe  Plymouth      4.5
# 4               Marylou's Coffee  Plymouth      3.5
# 5                        Dunkin'  Plymouth      1.5
# 6               Uncommon Grounds   Duxbury      4.5
# 7             The Farmer's Table  Plymouth      4.5
# 8                  Alltown Fresh  Plymouth      5.0
# 9                Will & Co. Cafe  Plymouth      4.5
# 10              Cumberland Farms  Plymouth      4.5
# 11                Marylou's News  Pembroke      3.0
# 12             Plane Jane  Place  Plymouth      4.0
# 13                 Stowells Café  Plymouth      4.5
# 14                       Dunkin'  Plymouth      1.0
# 15              Speedwell Coffee  Plymouth      4.5
# 16              Marylou's Coffee  Plymouth      3.0
# 17         Sandy's Coffee Corner    Hanson      4.5
# 18        The Moon and Back Cafe  Plympton      4.5
# 19             Off the Wall Kidz    Carver      4.5
# 20                       Dunkin'  Plymouth      2.0
# 21                Marylou's News  Plymouth      2.5
# 22               Gunther Tooties  Plymouth      3.5
# 23              The Coffee Trike    Boston      5.0
# 24                       Dunkin'  Plymouth      2.0
# 25                       Dunkin'  Plymouth      2.0
# 26             Water Street Cafe  Plymouth      3.5
# 27                    McDonald's  Plymouth      1.5
# 28                       Dunkin'  Plymouth      2.5
# 29                       Dunkin'  Plymouth      2.5
# 30              3A Cafe & Bakery  Plymouth      4.0
# 31            A Fork In The Road  Pembroke      5.0
# 32                       Dunkin'  Plymouth      1.0
# 33                      7-Eleven  Plymouth      1.5
# 34       Jenny's Pickle Pup Cafe   Duxbury      5.0
# 35                       Dunkin'  Plymouth      1.0
# 36                       Dunkin'  Plymouth      2.5
# 37                       Dunkin'   Duxbury      1.5
# 38               Makepeace Farms   Wareham      5.0
# 39  For Goodness Cakes Bake Shop    Carver      4.5
# 40              Cumberland Farms  Kingston      3.5
# 41                    McDonald's  Plymouth      1.5
# 42                       Dunkin'  Plymouth      1.0
# 43                    Caffe Nero  Plymouth      2.0
# 44        Chestnut Street Grille   Duxbury      3.5
# 45                    Dandy Cafe    Carver      3.5
# 46                         OROPA   Duxbury      5.0
# 47                       Dunkin'  Kingston      1.0
# 48                       Dunkin'    Carver      5.0
# 49                       Dunkin'  Kingston      3.0
#
#                               Coordinates  \
# 0                 [-70.686153, 41.955105]
# 1                 [-70.714909, 41.954063]
# 2                   [-70.66451, 41.95609]
# 3                 [-70.648494, 41.926233]
# 4   [-70.6525832039001, 41.9406878784855]
# 5   [-70.6587266586781, 41.9331525482117]
# 6                   [-70.68682, 42.04939]
# 7    [-70.6163622745905, 41.828891836875]
# 8                [-70.6576874, 41.933018]
# 9                   [-70.66576, 41.95721]
# 10  [-70.6878796876995, 41.9515882638283]
# 11                [-70.775461, 42.066377]
# 12                  [-70.72683, 41.90859]
# 13  [-70.5545890065162, 41.9167547176086]
# 14                  [-70.64523, 41.94306]
# 15                  [-70.72752, 41.91515]
# 16                  [-70.55403, 41.91364]
# 17                  [-70.85433, 42.04238]
# 18                  [-70.81395, 41.95193]
# 19                  [-70.81142, 41.93207]
# 20               [-70.713877, 41.9500968]
# 21  [-70.5527830123901, 41.8193916809856]
# 22    [-70.6663128733635, 41.95728210689]
# 23  [-71.0611114501953, 42.3527526855469]
# 24                 [-70.65619, 41.939119]
# 25                  [-70.68758, 41.97748]
# 26                   [-70.6613, 41.95555]
# 27              [-70.6576219, 41.9339887]
# 28                [-70.684471, 41.952712]
# 29    [-70.557088097092, 41.915842273373]
# 30                  [-70.68318, 41.97279]
# 31              [-70.8418499, 42.0429699]
# 32                [-70.735899, 41.910872]
# 33  [-70.6852237089106, 41.9741173116648]
# 34                  [-70.70798, 42.01131]
# 35              [-70.7079399, 41.9638599]
# 36                [-70.679714, 41.955878]
# 37                   [-70.6835, 42.02377]
# 38              [-70.7193283, 41.7837238]
# 39                [-70.765706, 41.886504]
# 40  [-70.7004346117374, 41.9839474147094]
# 41                [-70.686376, 41.952964]
# 42                   [-70.66268, 41.9543]
# 43               [-4.1422901, 50.3703384]
# 44                  [-70.68364, 42.02342]
# 45              [-70.7680283, 41.8878899]
# 46                  [-70.68281, 42.02489]
# 47               [-70.7161732, 41.969158]
# 48                  [-70.81011, 41.92825]
# 49                  [-70.71585, 41.98738]
#
#                                              Geometry
# 0   {'Type': 'Point', 'coordinates': [-70.686153, ...
# 1   {'Type': 'Point', 'coordinates': [-70.714909, ...
# 2   {'Type': 'Point', 'coordinates': [-70.66451, 4...
# 3   {'Type': 'Point', 'coordinates': [-70.648494, ...
# 4   {'Type': 'Point', 'coordinates': [-70.65258320...
# 5   {'Type': 'Point', 'coordinates': [-70.65872665...
# 6   {'Type': 'Point', 'coordinates': [-70.68682, 4...
# 7   {'Type': 'Point', 'coordinates': [-70.61636227...
# 8   {'Type': 'Point', 'coordinates': [-70.6576874,...
# 9   {'Type': 'Point', 'coordinates': [-70.66576, 4...
# 10  {'Type': 'Point', 'coordinates': [-70.68787968...
# 11  {'Type': 'Point', 'coordinates': [-70.775461, ...
# 12  {'Type': 'Point', 'coordinates': [-70.72683, 4...
# 13  {'Type': 'Point', 'coordinates': [-70.55458900...
# 14  {'Type': 'Point', 'coordinates': [-70.64523, 4...
# 15  {'Type': 'Point', 'coordinates': [-70.72752, 4...
# 16  {'Type': 'Point', 'coordinates': [-70.55403, 4...
# 17  {'Type': 'Point', 'coordinates': [-70.85433, 4...
# 18  {'Type': 'Point', 'coordinates': [-70.81395, 4...
# 19  {'Type': 'Point', 'coordinates': [-70.81142, 4...
# 20  {'Type': 'Point', 'coordinates': [-70.713877, ...
# 21  {'Type': 'Point', 'coordinates': [-70.55278301...
# 22  {'Type': 'Point', 'coordinates': [-70.66631287...
# 23  {'Type': 'Point', 'coordinates': [-71.06111145...
# 24  {'Type': 'Point', 'coordinates': [-70.65619, 4...
# 25  {'Type': 'Point', 'coordinates': [-70.68758, 4...
# 26  {'Type': 'Point', 'coordinates': [-70.6613, 41...
# 27  {'Type': 'Point', 'coordinates': [-70.6576219,...
# 28  {'Type': 'Point', 'coordinates': [-70.684471, ...
# 29  {'Type': 'Point', 'coordinates': [-70.55708809...
# 30  {'Type': 'Point', 'coordinates': [-70.68318, 4...
# 31  {'Type': 'Point', 'coordinates': [-70.8418499,...
# 32  {'Type': 'Point', 'coordinates': [-70.735899, ...
# 33  {'Type': 'Point', 'coordinates': [-70.68522370...
# 34  {'Type': 'Point', 'coordinates': [-70.70798, 4...
# 35  {'Type': 'Point', 'coordinates': [-70.7079399,...
# 36  {'Type': 'Point', 'coordinates': [-70.679714, ...
# 37  {'Type': 'Point', 'coordinates': [-70.6835, 42...
# 38  {'Type': 'Point', 'coordinates': [-70.7193283,...
# 39  {'Type': 'Point', 'coordinates': [-70.765706, ...
# 40  {'Type': 'Point', 'coordinates': [-70.70043461...
# 41  {'Type': 'Point', 'coordinates': [-70.686376, ...
# 42  {'Type': 'Point', 'coordinates': [-70.66268, 4...
# 43  {'Type': 'Point', 'coordinates': [-4.1422901, ...
# 44  {'Type': 'Point', 'coordinates': [-70.68364, 4...
# 45  {'Type': 'Point', 'coordinates': [-70.7680283,...
# 46  {'Type': 'Point', 'coordinates': [-70.68281, 4...
# 47  {'Type': 'Point', 'coordinates': [-70.7161732,...
# 48  {'Type': 'Point', 'coordinates': [-70.81011, 4...
# 49  {'Type': 'Point', 'coordinates': [-70.71585, 4...

# %%
for i in range(len(starbucks_list)):
    starbucks_list[i] = starbucks_list[i][starbucks_list[i].Name == "Starbucks"]

starbucks_list[234]
# Out:
#         Name       City  Raiting                            Coordinates  \
# 0  Starbucks  Lake Mary      3.5                [-81.352706, 28.755523]
# 1  Starbucks  Lake Mary      2.5                [-81.357871, 28.778502]
# 2  Starbucks    Sanford      3.0                 [-81.33394, 28.798637]
# 3  Starbucks    Sanford      3.5  [-81.3347583264112, 28.8117523803962]
#
#                                             Geometry
# 0  {'Type': 'Point', 'coordinates': [-81.352706, ...
# 1  {'Type': 'Point', 'coordinates': [-81.357871, ...
# 2  {'Type': 'Point', 'coordinates': [-81.33394, 2...
# 3  {'Type': 'Point', 'coordinates': [-81.33475832...

# %%
starbucks_dfs = pd.concat(starbucks_list)

# %%
starbucks_dfs
# Out:
#          Name         City  Raiting                           Coordinates  \
# 0   Starbucks     Plymouth      3.0               [-70.686153, 41.955105]
# 1   Starbucks     Plymouth      2.5               [-70.714909, 41.954063]
# 0   Starbucks      Madison      3.5               [-89.397007, 43.074789]
# 1   Starbucks      Madison      4.0               [-89.386866, 43.075516]
# 2   Starbucks      Madison      3.5  [-89.382702182027, 43.0739068926383]
# ..        ...          ...      ...                                   ...
# 38  Starbucks     Saratoga      3.0               [-122.03232, 37.258709]
# 39  Starbucks  Santa Clara      3.5               [-121.967822, 37.35179]
# 40  Starbucks    Sunnyvale      2.5                [-122.03034, 37.38834]
# 41  Starbucks     Campbell      3.5              [-121.966517, 37.292856]
# 42  Starbucks     Campbell      2.5           [-121.9627709, 37.29466707]
#
#                                              Geometry
# 0   {'Type': 'Point', 'coordinates': [-70.686153, ...
# 1   {'Type': 'Point', 'coordinates': [-70.714909, ...
# 0   {'Type': 'Point', 'coordinates': [-89.397007, ...
# 1   {'Type': 'Point', 'coordinates': [-89.386866, ...
# 2   {'Type': 'Point', 'coordinates': [-89.38270218...
# ..                                                ...
# 38  {'Type': 'Point', 'coordinates': [-122.03232, ...
# 39  {'Type': 'Point', 'coordinates': [-121.967822,...
# 40  {'Type': 'Point', 'coordinates': [-122.03034, ...
# 41  {'Type': 'Point', 'coordinates': [-121.966517,...
# 42  {'Type': 'Point', 'coordinates': [-121.9627709...
#
# [10957 rows x 5 columns]

# %%
#df_schools = ya.get_coords("Schools", "Los Angeles")
#df_web_design = ya.get_coords("Web Design", "Los Angeles")
#df_web_design

# %%
def generateBaseMap(default_location=[34.0397, -118.2703], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
#df_Airport = ya.get_coords("Airport", "Los Angeles")
# Out:
# The status code is 400
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-543f466462ea> in <module>
# ----> 1 df_Airport = ya.get_coords("Airport", "Tartu")
#
# ~/Documents/mongoProject/src/yelp_api.py in get_coords(company, city)
#      26     coords_2 = []
#      27
# ---> 28     for i in api_response["businesses"]:
#      29         coords.append(i["coordinates"])
#      30         names.append(i["name"])
#
# KeyError: 'businesses'

# %%
df_Airport
df_Vegan = ya.get_coords("Vegan Restaurant", "Los Angeles")
# Out:
# The status code is 200

# %%
base_map = generateBaseMap()
base_map.add_child(folium.ClickForMarker(popup='Potential Location'))
for i in df_starbucks["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="coffee", color="darkred") ,popup="Starbucks").add_to(base_map)
for i in df_schools["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="graduation-cap", color="blue") ,popup="Schools").add_to(base_map)
for i in df_web_design["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="paint-brush", color="green") ,popup="Web Design").add_to(base_map)
for i in df_Airport["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="plane", color="red") ,popup="Airport").add_to(base_map)
for i in df_Vegan["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="leaf", color="darkblue") ,popup="Vegan food").add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_Vegan
# Out:
# The status code is 200
#                                          Name             City  Raiting  \
# 0               Sage Vegan Bistro - Echo Park      Los Angeles      4.0
# 1                                  Crossroads      Los Angeles      4.0
# 2                             SunCafe Organic      Studio City      4.5
# 3                                 Little Pine      Los Angeles      4.5
# 4              Gracias Madre - West Hollywood   West Hollywood      4.0
# 5                  Cafe Gratitude - Larchmont      Los Angeles      4.0
# 6                      BESTIES Vegan Paradise      Los Angeles      5.0
# 7                              The Grain Cafe      Los Angeles      4.5
# 8                              Cafe Gratitude      Los Angeles      4.0
# 9                         Flore Vegan Cuisine      Los Angeles      4.0
# 10                                un solo sol      Los Angeles      4.5
# 11                            Shojin Downtown      Los Angeles      4.0
# 12                            Real Food Daily   West Hollywood      4.0
# 13                        The Vegan Hooligans      Los Angeles      4.5
# 14                  Powerplant Superfood Cafe      Los Angeles      4.5
# 15      Sage Plant Based Bistro - Culver City      Culver City      4.0
# 16                      Inomoni Vegan Dim Sum      Los Angeles      5.0
# 17                                  Pura Vita   West Hollywood      4.5
# 18                                Stuff I Eat        Inglewood      4.5
# 19                        Monty's Good Burger      Los Angeles      4.5
# 20                                 Todo Verde      Los Angeles      5.0
# 21                                   OG Wingz          Burbank      5.0
# 22                                   LA Vegan      Los Angeles      4.0
# 23                                   Elf Café      Los Angeles      4.5
# 24                            The Vegan Joint      Los Angeles      4.0
# 25                           Nic's on Beverly      Los Angeles      4.5
# 26                              My Vegan Gold      Los Angeles      4.5
# 27                           Green Table Cafe      Los Angeles      4.5
# 28                                   by CHLOE      Los Angeles      4.0
# 29                            The Vegan Joint      Los Angeles      4.0
# 30                Elderberries Threefold Cafe      Los Angeles      4.0
# 31                         Shojin Culver City      Los Angeles      4.5
# 32                                       HOPE      Studio City      4.5
# 33                      Plant Food For People      Los Angeles      4.5
# 34                                 Ramen Hood      Los Angeles      4.5
# 35                                    Vromage      Los Angeles      5.0
# 36                                      Jewel      Los Angeles      4.5
# 37      Araya's Place - Thai Vegan Restaurant      Los Angeles      4.5
# 38                                     Au Lac      Los Angeles      4.0
# 39  The Good Good  - Vegan Kitchen + Bakeshop      Los Angeles      5.0
# 40                               Veggie House      Los Angeles      4.5
# 41                          True Food Kitchen         Pasadena      4.0
# 42                                    Organix      Los Angeles      4.5
# 43                    Krimsey's Cajun Kitchen  North Hollywood      4.5
# 44                                Avocadamama      Los Angeles      4.5
# 45                     The Butcher's Daughter           Venice      4.0
# 46                    Gratitude Kitchen & Bar    Beverly Hills      4.0
# 47                          True Food Kitchen     Santa Monica      4.0
# 48                                 Sugar Taco      Los Angeles      4.5
# 49                                   My Vegan         Pasadena      4.0
#
#                               Coordinates  \
# 0                [-118.258714, 34.077123]
# 1                  [-118.37011, 34.08342]
# 2         [-118.366539, 34.1385791989621]
# 3                  [-118.26677, 34.10768]
# 4   [-118.386972025037, 34.0807951106153]
# 5                  [-118.32404, 34.08279]
# 6                  [-118.29584, 34.09523]
# 7                  [-118.32758, 34.04762]
# 8   [-118.232452260713, 34.0456533607716]
# 9   [-118.279427202132, 34.0912104093655]
# 10                [-118.21915, 34.047022]
# 11             [-118.2382339, 34.0443222]
# 12                 [-118.37618, 34.07858]
# 13             [-118.2152377, 34.1343453]
# 14               [-118.361676, 34.050409]
# 15                [-118.41216, 34.006538]
# 16                 [-118.17805, 34.08172]
# 17  [-118.369686045023, 34.0906660191608]
# 18              [-118.3518651, 33.963434]
# 19                 [-118.30876, 34.06469]
# 20                 [-118.24137, 34.02969]
# 21               [-118.298176, 34.176255]
# 22                  [-118.42336, 33.9926]
# 23               [-118.264616, 34.077812]
# 24  [-118.411620547176, 34.0285966348823]
# 25                  [-118.3696, 34.07638]
# 26             [-118.2831401, 34.0951603]
# 27               [-118.37115, 34.0522237]
# 28             [-118.25858833, 34.102695]
# 29             [-118.2513123, 34.0357895]
# 30              [-118.354408, 34.0978951]
# 31  [-118.428680419922, 33.9966735839844]
# 32             [-118.3919406, 34.1436294]
# 33  [-118.196769714355, 34.1092338562012]
# 34             [-118.2486189, 34.0505289]
# 35             [-118.3643588, 34.0978951]
# 36                 [-118.28427, 34.08307]
# 37             [-118.3659884, 34.0763201]
# 38  [-118.250936711212, 34.0563590452504]
# 39            [-118.2957335, 34.09105983]
# 40                 [-118.34787, 34.12858]
# 41               [-118.153869, 34.145451]
# 42               [-118.204862, 34.139714]
# 43           [-118.4140255, 34.186357166]
# 44                 [-118.24001, 34.11491]
# 45                 [-118.46916, 33.99166]
# 46  [-118.401442542672, 34.0708531588601]
# 47             [-118.4944629, 34.0129682]
# 48           [-118.34784433, 34.08370683]
# 49        [-118.147798, 34.1344204136884]
#
#                                              Geometry
# 0   {'Type': 'Point', 'coordinates': [-118.258714,...
# 1   {'Type': 'Point', 'coordinates': [-118.37011, ...
# 2   {'Type': 'Point', 'coordinates': [-118.366539,...
# 3   {'Type': 'Point', 'coordinates': [-118.26677, ...
# 4   {'Type': 'Point', 'coordinates': [-118.3869720...
# 5   {'Type': 'Point', 'coordinates': [-118.32404, ...
# 6   {'Type': 'Point', 'coordinates': [-118.29584, ...
# 7   {'Type': 'Point', 'coordinates': [-118.32758, ...
# 8   {'Type': 'Point', 'coordinates': [-118.2324522...
# 9   {'Type': 'Point', 'coordinates': [-118.2794272...
# 10  {'Type': 'Point', 'coordinates': [-118.21915, ...
# 11  {'Type': 'Point', 'coordinates': [-118.2382339...
# 12  {'Type': 'Point', 'coordinates': [-118.37618, ...
# 13  {'Type': 'Point', 'coordinates': [-118.2152377...
# 14  {'Type': 'Point', 'coordinates': [-118.361676,...
# 15  {'Type': 'Point', 'coordinates': [-118.41216, ...
# 16  {'Type': 'Point', 'coordinates': [-118.17805, ...
# 17  {'Type': 'Point', 'coordinates': [-118.3696860...
# 18  {'Type': 'Point', 'coordinates': [-118.3518651...
# 19  {'Type': 'Point', 'coordinates': [-118.30876, ...
# 20  {'Type': 'Point', 'coordinates': [-118.24137, ...
# 21  {'Type': 'Point', 'coordinates': [-118.298176,...
# 22  {'Type': 'Point', 'coordinates': [-118.42336, ...
# 23  {'Type': 'Point', 'coordinates': [-118.264616,...
# 24  {'Type': 'Point', 'coordinates': [-118.4116205...
# 25  {'Type': 'Point', 'coordinates': [-118.3696, 3...
# 26  {'Type': 'Point', 'coordinates': [-118.2831401...
# 27  {'Type': 'Point', 'coordinates': [-118.37115, ...
# 28  {'Type': 'Point', 'coordinates': [-118.2585883...
# 29  {'Type': 'Point', 'coordinates': [-118.2513123...
# 30  {'Type': 'Point', 'coordinates': [-118.354408,...
# 31  {'Type': 'Point', 'coordinates': [-118.4286804...
# 32  {'Type': 'Point', 'coordinates': [-118.3919406...
# 33  {'Type': 'Point', 'coordinates': [-118.1967697...
# 34  {'Type': 'Point', 'coordinates': [-118.2486189...
# 35  {'Type': 'Point', 'coordinates': [-118.3643588...
# 36  {'Type': 'Point', 'coordinates': [-118.28427, ...
# 37  {'Type': 'Point', 'coordinates': [-118.3659884...
# 38  {'Type': 'Point', 'coordinates': [-118.2509367...
# 39  {'Type': 'Point', 'coordinates': [-118.2957335...
# 40  {'Type': 'Point', 'coordinates': [-118.34787, ...
# 41  {'Type': 'Point', 'coordinates': [-118.153869,...
# 42  {'Type': 'Point', 'coordinates': [-118.204862,...
# 43  {'Type': 'Point', 'coordinates': [-118.4140255...
# 44  {'Type': 'Point', 'coordinates': [-118.24001, ...
# 45  {'Type': 'Point', 'coordinates': [-118.46916, ...
# 46  {'Type': 'Point', 'coordinates': [-118.4014425...
# 47  {'Type': 'Point', 'coordinates': [-118.4944629...
# 48  {'Type': 'Point', 'coordinates': [-118.3478443...
# 49  {'Type': 'Point', 'coordinates': [-118.147798,...
