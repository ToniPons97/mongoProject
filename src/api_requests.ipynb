# %%
import yelp_api as ya
import folium
from time import sleep
import pandas as pd
# %store -r cities_df
from IPython.display import clear_output

# %%
starbucks_list = []

for i in cities_df:
    starbucks_list.append(ya.get_coords("Starbucks", i))
    sleep(0.5)

# %%
for i in range(len(starbucks_list)):
    starbucks_list[i] = starbucks_list[i][starbucks_list[i].Name == "Starbucks"]

starbucks_list[0]
# Out:
#         Name           City  Raiting                  Coordinates  \
# 0  Starbucks    Maple Grove      4.0      [-93.450222, 45.099599]
# 1  Starbucks    Maple Grove      2.5      [-93.491018, 45.125306]
# 2  Starbucks    Maple Grove      3.0      [-93.474474, 45.136267]
# 3  Starbucks  Brooklyn Park      3.0       [-93.37835, 45.091167]
# 4  Starbucks  Brooklyn Park      3.5      [-93.370021, 45.135666]
# 5  Starbucks  Brooklyn Park      3.0       [-93.35877, 45.125984]
# 6  Starbucks  Brooklyn Park      1.0  [-93.35749527, 45.12531295]
# 7  Starbucks       Plymouth      2.5       [-93.45135, 45.031345]
# 8  Starbucks       Champlin      3.5      [-93.390743, 45.158694]
# 9  Starbucks        Crystal      4.5       [-93.364742, 45.05424]
#
#                                             Geometry
# 0  {'type': 'Point', 'coordinates': [-93.450222, ...
# 1  {'type': 'Point', 'coordinates': [-93.491018, ...
# 2  {'type': 'Point', 'coordinates': [-93.474474, ...
# 3  {'type': 'Point', 'coordinates': [-93.37835, 4...
# 4  {'type': 'Point', 'coordinates': [-93.370021, ...
# 5  {'type': 'Point', 'coordinates': [-93.35877, 4...
# 6  {'type': 'Point', 'coordinates': [-93.35749527...
# 7  {'type': 'Point', 'coordinates': [-93.45135, 4...
# 8  {'type': 'Point', 'coordinates': [-93.390743, ...
# 9  {'type': 'Point', 'coordinates': [-93.364742, ...

# %%
starbucks_dfs = pd.concat(starbucks_list)
starbucks_dfs
# Out:
#          Name           City  Raiting                            Coordinates  \
# 0   Starbucks    Maple Grove      4.0                [-93.450222, 45.099599]
# 1   Starbucks    Maple Grove      2.5                [-93.491018, 45.125306]
# 2   Starbucks    Maple Grove      3.0                [-93.474474, 45.136267]
# 3   Starbucks  Brooklyn Park      3.0                 [-93.37835, 45.091167]
# 4   Starbucks  Brooklyn Park      3.5                [-93.370021, 45.135666]
# ..        ...            ...      ...                                    ...
# 8   Starbucks     Lake Bluff      2.5                [-87.879978, 42.280956]
# 9   Starbucks     Lake Bluff      3.5                [-87.873803, 42.279151]
# 10  Starbucks      Mundelein      2.0               [-88.042514, 42.2797884]
# 11  Starbucks      Mundelein      3.5                [-88.045288, 42.284435]
# 12  Starbucks    Lake Forest      1.0  [-87.8629917195993, 42.2548486915967]
#
#                                              Geometry
# 0   {'type': 'Point', 'coordinates': [-93.450222, ...
# 1   {'type': 'Point', 'coordinates': [-93.491018, ...
# 2   {'type': 'Point', 'coordinates': [-93.474474, ...
# 3   {'type': 'Point', 'coordinates': [-93.37835, 4...
# 4   {'type': 'Point', 'coordinates': [-93.370021, ...
# ..                                                ...
# 8   {'type': 'Point', 'coordinates': [-87.879978, ...
# 9   {'type': 'Point', 'coordinates': [-87.873803, ...
# 10  {'type': 'Point', 'coordinates': [-88.042514, ...
# 11  {'type': 'Point', 'coordinates': [-88.045288, ...
# 12  {'type': 'Point', 'coordinates': [-87.86299171...
#
# [10518 rows x 5 columns]

# %%
starbucks_dfs.to_json("../output/starbucks.json", orient="records")

# %%
airports_dfs.columns
# Out:
# Index(['Name', 'City', 'Raiting', 'Coordinates', 'Geometry'], dtype='object')

# %%
airports_df = []
for i in cities_df:
    airports_df.append(ya.get_coords("Airport", i))
    sleep(0.5)
# Out:
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200

# %%
airports_dfs = pd.concat(airports_df)

# %%
for i in airports_dfs["Coordinates"]:
    if i == [None, None]

# %%
airports_dfs = airports_dfs.loc[airports_dfs["Geometry"]!= {'type': 'Point', 'coordinates': [None, None]}]

# %%
for i in airports_dfs["Geometry"]:
    if i == {'type':'Point', 'coordinates': [None, None]}:
        print(i)

# %%
airports_dfs.to_json("../output/airports.json", orient="records")

# %%
vegan_df = []
for i in cities_df:
    vegan_df.append(ya.get_coords("Vegan Restaurant", i))
    sleep(0.5)
# Out:
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200

# %%
vegan_dfs = pd.concat(vegan_df)

# %%
for i in vegan_dfs["Geometry"]:
    if i == {"type": "Point", "coordinates": [None, None]}:
        print(i)

# %%
vegan_dfs.to_json("../output/vegan.json", orient="records")

# %%
schools_dfs.to_json("../output/schools.json", orient="records")

# %%
schools_df = []
for i in cities_df:
    schools_df.append(ya.get_coords("Schools", i))
    sleep(0.5)
# Out:
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200
# The status code is 200

# %%
schools_dfs = pd.concat(schools_df)

# %%
for i in schools_dfs["Geometry"]:
    if i == {"type": "Point", "coordinates": [None, None]}:
        print(i)
# Out:
# {'type': 'Point', 'coordinates': [None, None]}
# {'type': 'Point', 'coordinates': [None, None]}
# {'type': 'Point', 'coordinates': [None, None]}
# {'type': 'Point', 'coordinates': [None, None]}

# %%
schools_dfs = schools_dfs.loc[schools_dfs["Geometry"]!= {'type': 'Point', 'coordinates': [None, None]}]

# %%
schools_dfs.to_json("../output/schools.json", orient="records")

# %%
def generateBaseMap(default_location=[34.0397, -118.2703], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
base_map = generateBaseMap()
base_map.add_child(folium.ClickForMarker(popup='Potential Location'))
for i in df_starbucks["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="coffee", color="darkred") ,popup="Starbucks").add_to(base_map)
for i in df_schools["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="graduation-cap", color="blue") ,popup="Schools").add_to(base_map)
for i in df_web_design["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="paint-brush", color="green") ,popup="Web Design").add_to(base_map)
for i in df_Airport["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="plane", color="red") ,popup="Airport").add_to(base_map)
for i in df_Vegan["Coordinates"]:
    folium.Marker(i[::-1], icon=folium.Icon(prefix="fa",icon="leaf", color="darkblue") ,popup="Vegan food").add_to(base_map)
base_map
